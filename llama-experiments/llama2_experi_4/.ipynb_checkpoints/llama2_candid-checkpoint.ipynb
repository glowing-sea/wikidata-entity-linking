# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Apr  8 13:05:28 2024

@author: salman
"""
import csv
import ast

import requests
import json
import openai
import os
import re
import random
import time

# %%
"""
All Haoting's code is in this block  !

Set up guide

Step 1: install llama_cpp

# CPU
pip install --upgrade --quiet  llama-cpp-python
# Mac Metal
CMAKE_ARGS="-DLLAMA_METAL=on" FORCE_CMAKE=1 pip install llama-cpp-python
# Cuda
CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python

Reference
<https://python.langchain.com/docs/integrations/llms/llamacpp/>
<https://llama-cpp-python.readthedocs.io/en/latest/api-reference/>

Step 2: donwload the model

<https://huggingface.co/TheBloke/Llama-2-7B-GGUF/tree/main>

"""

# Libraries
from llama_cpp import Llama
import pandas as pd

# Model initialisation parameters
MODEL_PATH = "../llms/llama-2-7b.Q4_K_M.gguf"
N_GPU_LAYERS = -1 # GPU acceleration
SEED = 2024
N_CONTEXT = 4096

# Model prompting parameters
TEMPERATURE = 0.1 # creativity of output
MAX_TOKENS = 100 # maximum token generated by the llm
TOP_P = 0.95 # sampling the top p probability mass
STOP = [] # a list of output token that stop the llm to generate more response

# Prompt construction parameters
MAX_CANDIDATES_PER_PROMPT = 30 # if there are too many candidate, split into several prompt

# Global variables
llm = None

# Set random function
random.seed(SEED)


def load_llm():
    """ Initialise llama2 """
    global llm
    llm = Llama(model_path=MODEL_PATH, 
                n_gpu_layers=N_GPU_LAYERS,
                seed=SEED,
                n_ctx = N_CONTEXT)

def llama2_query_best_candid(entity: str, candidates: list, context: str, verbose=False) -> str | None:
    """
    Ask the llm to choose a Wiki ID from a number of candidates

    if verbose = Ture, display candidates
    """

    # Convert to data frame
    candidates = pd.DataFrame(candidates, columns=['WikiID', 'instanceOrSubclassOf', 'hasDescription'])
    candidates.set_index('WikiID', inplace=True)
    candidates['hasLabel'] = entity

    # Drop r# Drop rows with None or empty list/set in 'hasDescription'
    candidates = candidates.dropna(subset=['hasDescription'])  # Drop None values
    candidates = candidates[candidates['hasDescription'].apply(lambda x: x != [] and x != set())]

    # Print prelogue
    if verbose:
        print('\n' + ("=" * 100))
        print("NEL task starts\n")
        print(f"Entity = '{entity}'")
        print(f"Context = '{context}'")
        print(("=" * 100) + '\n')
        print("The following table shows all candidates retrieved by SPARQL query.")
        display(candidates)

    # Obtain result
    result = llama2_query_best_candid_recursive(entity, candidates, context, verbose)


    # Print epilogue
    if verbose:
        print('\n' + ("=" * 100))
        print("NEL task ends\n")
        print(f"Predicted ID = '{result}'")
        print(("=" * 100) + '\n')

    return result

def llama2_query_best_candid_recursive(entity: str, candidates: pd.DataFrame, context: str, verbose) -> str | None:
    """
    Ask the llm to choose a Wiki ID from a number of candidates

    if verbose = Ture, display candidates
    """

    # For small number of candidates, do it in a single prompt
    if len(candidates) <= MAX_CANDIDATES_PER_PROMPT:
        return llama2_query_best_candid_small(entity, context, candidates, verbose)
    
    # For the number of candiates larger than the threshold, split the candidate set
    if verbose:
        print(f"\n[!!!] There are too many candidates (> {MAX_CANDIDATES_PER_PROMPT}) for the llm to choose. The candidates set will be split and multiple prompts will be made.\n")

    candidates_partition = [candidates[i:i + MAX_CANDIDATES_PER_PROMPT] for i in range(0, candidates.shape[0], MAX_CANDIDATES_PER_PROMPT)]
    best_candids = []
    for candidate_subset in candidates_partition:
        result = llama2_query_best_candid_small(entity, context, candidate_subset, verbose)
        if result is not None:
            best_candids.append(result)
    
    # Gather the correct answer from each subset of candidates
    if len(best_candids) == 0:
        return None
    elif len(best_candids) == 1:
        return best_candids[0]
    elif len(best_candids) > 1:
        new_candidates = candidates.loc[best_candids]
        return llama2_query_best_candid_recursive(entity, new_candidates, context, verbose=verbose)


def llama2_query_best_candid_small(entity: str, context: str, candidates: pd.DataFrame, verbose: bool) -> str | None:
    """
    Ask the llm to choose a Wiki ID from no more than MAX_CANDIDATES_PER_PROMPT candidates

    verbose = True, then print the prompt, response, and parsed output
    """
    global llm

    # No candidate, return None
    if len(candidates) == 0:
        return None
    
    # One candidate, return the only one
    if len(candidates) == 1:
        return candidates.iloc[0].name
    
    # More than one, ask llm
    assert(len(candidates) <= MAX_CANDIDATES_PER_PROMPT)

    # Construct candidate string
    # candidates_string = ''
    # count = 1
    # for index, row in candidates.iterrows(): 
    #     candidates_string = candidates_string + f"Option {str(count)}: {row['hasDescription'][0]}\n"
    #     count += 1

    candidates_string = ''
    count = 1
    for index, row in candidates.iterrows():
        candidates_string = candidates_string + f"Option {str(count)}, Class: {str(row['instanceOrSubclassOf'])}, Description: {str(row['hasDescription'])}\n"
        count += 1

    # Construct prompt
    prompt = f"""As a linguistic specialist, consider the following task:
Given the sentence "{context}", what does the entity "{entity}" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:

{candidates_string}
The correct answer is:

Option """
    
    # Check the tokens is below the context windows
    tokens = llm.tokenizer().tokenize(bytes(prompt, 'utf-8'))
    if (len(tokens) + MAX_TOKENS) > N_CONTEXT:
        return None

    # Get response
    response = llm(
      prompt,
      max_tokens=MAX_TOKENS,
      temperature=TEMPERATURE,
      top_p=TOP_P,
      stop=STOP,
      echo=False # Echo the prompt back in the output
      )
    
    response = response['choices'][0]['text']

    if verbose:
        print()
        print(prompt + response)
        print()
    
    # Parse response
    match = re.search(r'(\d+)', response)

    # Prevent the llm to generate a non-existing ID
    if match:
        if int(match.group(1)) - 1 < len(candidates):
            return candidates.index[int(match.group(1)) - 1]
    return None

# Execute Code
load_llm()
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from ../llms/llama-2-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 32
# llm_load_print_meta: n_layer          = 32
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 4096
# llm_load_print_meta: n_embd_v_gqa     = 4096
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 11008
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: model type       = 7B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 6.74 B
# llm_load_print_meta: model size       = 3.80 GiB (4.84 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.30 MiB
# ggml_backend_metal_buffer_from_ptr: allocated buffer, size =  3820.94 MiB, ( 3821.00 / 21845.34)
# llm_load_tensors: offloading 32 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 33/33 layers to GPU
# llm_load_tensors:        CPU buffer size =    70.31 MiB
# llm_load_tensors:      Metal buffer size =  3820.93 MiB
# ..................................................................................................
# llama_new_context_with_model: n_ctx      = 4096
# llama_new_context_with_model: n_batch    = 512
# llama_new_context_with_model: n_ubatch   = 512
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M1 Max
# ggml_metal_init: picking default device: Apple M1 Max
# ggml_metal_init: using embedded metal library
# ggml_metal_init: GPU name:   Apple M1 Max
# ggml_metal_init: GPU family: MTLGPUFamilyApple7  (1007)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction support   = true
# ggml_metal_init: simdgroup matrix mul. support = true
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 22906.50 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =  2048.00 MiB, ( 5870.81 / 21845.34)
# llama_kv_cache_init:      Metal KV buffer size =  2048.00 MiB
# llama_new_context_with_model: KV self size  = 2048.00 MiB, K (f16): 1024.00 MiB, V (f16): 1024.00 MiB
# llama_new_context_with_model:        CPU  output buffer size =     0.12 MiB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   296.02 MiB, ( 6166.83 / 21845.34)
# llama_new_context_with_model:      Metal compute buffer size =   296.00 MiB
# llama_new_context_with_model:        CPU compute buffer size =    16.01 MiB
# llama_new_context_with_model: graph nodes  = 1030
# llama_new_context_with_model: graph splits = 2
# AVX = 0 | AVX_VNNI = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 | MATMUL_INT8 = 0 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '32', 'llama.context_length': '4096', 'llama.attention.head_count': '32', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '11008', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'LLaMA v2'}
# Using fallback chat format: None

# %%
from collections import defaultdict

# Definintion of  endpoint and headers
endpoint_url = "https://query.wikidata.org/sparql"
headers = {"Accept": "application/sparql-results+json"}

def sparql_query_type(label):
    '''
    Input: Entity Label
    Functionality: Extracting the URI with relevant information from Wikidata SPARQL endpoint
    Return: List of QIDs for entity_label.
    '''
    
    
    query_des = 'SELECT ?entity ?type ?typeLabel ?subclassLabel ?entityDescription WHERE {?entity rdfs:label \"'+label+'\"@en . OPTIONAL { ?entity wdt:P31 ?type .} OPTIONAL {?entity wdt:P279 ?subclass.} FILTER (!bound(?type) || ?type != wd:Q4167410) SERVICE wikibase:label { bd:serviceParam wikibase:language "en".} }'
    

    response = requests.get(endpoint_url, headers=headers, params={'query': query_des, 'format': 'json'})
    items_with_classes = defaultdict(list)
    items_with_descr = defaultdict(list)
    # Process the response
    if response.ok:
        data = response.json()
        for result in data['results']['bindings']:
            #print(result)
        
        
            entity_uri = result['entity']['value'].split('/')[-1]
            type_label = result.get('typeLabel')
            subclass = result.get('subclassLabel')
            desc = result.get('entityDescription')
        
            type_uri = ''
            class_uri = ''
            descr = ''
        
            if type_label:
                type_uri = result['typeLabel']['value']
        
            if subclass:
                class_uri = result['subclassLabel']['value']
            
            if desc:
                descr = result['entityDescription']['value']
        
        
            if type_uri !='':
                items_with_classes[entity_uri].append(type_uri)
            
            if class_uri != '':
                items_with_classes[entity_uri].append(class_uri)
        
            if descr != '':
                if entity_uri not in items_with_descr or not items_with_descr[entity_uri]:
                    items_with_descr[entity_uri].append(descr)
    
    
    return [(entity_uri, classes, items_with_descr[entity_uri]) for entity_uri, classes in items_with_classes.items()]   



def find_case_sensitive_term(text, search_term):
    # Compile a regex pattern for case-insensitive matching
    pattern = re.compile(re.escape(search_term), re.IGNORECASE)
    
    # Find all matches in the text
    matches = pattern.findall(text)
    
    # Return the list of matches
    return matches[0]


file_path = './test_full.json'

n=0
P,R,F = 0,0,0

with open(file_path, 'r') as file:
    data = json.load(file)
    data_samples = random.sample(data, 100)
    
    for content in data_samples:
        entity_label = content['string']
        query_text = content['text']
        c_id = content['correct_id']
        
        if entity_label in query_text:
            entity_label = entity_label
        else:
            entity_label = find_case_sensitive_term(query_text, entity_label)
        
        start_time = time.time()

        n+=1
        k=1
        
        uri = sparql_query_type(entity_label)
        
        while not uri and k<5:
            uri = sparql_query_type(entity_label)
            k+=1
            
        candidates = ""
        
        
        if uri:
            R+=1
        
        sparql_time = time.time() - start_time

        #print(n, "List of Candidates:\n", candidates)
        

    
        ########################################################
        ##            Candidate Selection By GPT              ##
        ########################################################
        
        start_time = time.time()
    
        candidates = uri
        candids = ''
        for cands in candidates:
            candids = candids + cands[0]+ ", Class: " + str(cands[1]) + ", Description: " + str(cands[2]) + "\n"
            
        #print(candids)
        # Call the function with the extracted information
        ID = llama2_query_best_candid(entity_label, candidates, query_text, verbose=True)
        
        if ID is not None and c_id == ID:
            print(f"{n} Wiki ID Matched")
            P += 1
        
        elif ID == 'NA' or ID == "return 'NA'" or ID == None:
            if entity_label == entity_label.lower():
                entity_label = entity_label.capitalize()
            else:
                entity_label = entity_label.lower()
                
            candidates = sparql_query_type(entity_label)
            k=1
            while not candidates and k<3:
                candidates = sparql_query_type(entity_label)
                k+=1
            
            candids = ''

            for cands in candidates:
                candids = candids + cands[0]+ ", Class: " + str(cands[1]) + ", Description: " + str(cands[2]) + "\n"
            
            ID = llama2_query_best_candid(entity_label, candidates, query_text, verbose=True)
            
            if ID is not None and c_id == ID:
                print(f"{n}  '{entity_label}' - Wiki ID Matched")
                P += 1

        llm_time = time.time() - start_time 
                
        candidss = n, query_text, candidates, entity_label, c_id, ID, sparql_time, llm_time
        
        with open('./Sample1.csv', 'a') as file:
              writer = csv.writer(file, delimiter=',')
              writer.writerow(candidss)

r=100*n/n
p = 100*P/n

print("###########  PERFORMANCE   ###########")    

print(f"Precision:{(P/n)*100} %")
print(f"Recall: {100*R/n} %")
print(f" Fmeasure = {2*p*r/(p+r)} %")

print("#####################################")
# Out:
# ====================================================================================================
# NEL task starts
#
# Entity = 'East Asia'
# Context = ' invasion, the conquest of East Asia by Japan that cuts the Chinese conquests in Russia and Europe down to the limits of the former Austro-Hungarian empire, and the Japanese '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#             instanceOrSubclassOf  \
# WikiID
# Q27231       [geographic region]
# Q5327728                 [album]
# Q15761181   [scientific journal]
# Q58558114    [scholarly article]
# Q86075977    [scholarly article]
# Q125592707   [scholarly article]
# Q125857107   [scholarly article]
#
#                                              hasDescription   hasLabel
# WikiID
# Q27231                             [eastern region of Asia]  East Asia
# Q5327728                         [album by Miyuki Nakajima]  East Asia
# Q15761181                                         [journal]  East Asia
# Q58558114                                         [article]  East Asia
# Q86075977   [scientific article published on 01 March 2014]  East Asia
# Q125592707           [scientific article published in 2009]  East Asia
# Q125857107           [scientific article published in 2010]  East Asia
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       7.99 ms /    91 runs   (    0.09 ms per token, 11394.94 tokens per second)
# llama_print_timings: prompt eval time =    1024.36 ms /   274 tokens (    3.74 ms per token,   267.48 tokens per second)
# llama_print_timings:        eval time =    1873.81 ms /    90 runs   (   20.82 ms per token,    48.03 tokens per second)
# llama_print_timings:       total time =    3028.39 ms /   364 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " invasion, the conquest of East Asia by Japan that cuts the Chinese conquests in Russia and Europe down to the limits of the former Austro-Hungarian empire, and the Japanese ", what does the entity "East Asia" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['geographic region'], Description: ['eastern region of Asia']
# Option 2, Class: ['album'], Description: ['album by Miyuki Nakajima']
# Option 3, Class: ['scientific journal'], Description: ['journal']
# Option 4, Class: ['scholarly article'], Description: ['article']
# Option 5, Class: ['scholarly article'], Description: ['scientific article published on 01 March 2014']
# Option 6, Class: ['scholarly article'], Description: ['scientific article published in 2009']
# Option 7, Class: ['scholarly article'], Description: ['scientific article published in 2010']
#
# The correct answer is:
#
# Option 3, Class: ['scientific journal'], Description: ['journal']
#
# ### Explanation
#
# The entity "East Asia" refers to the scientific journal. The reason for this choice is that the sentence is a quote from an article published in 2014 and the description of the entity "East Asia" includes the year 2014, which indicates that it is a scientific journal.
#
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q15761181'
# ====================================================================================================
#
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Hell'
# Context = ' is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                        instanceOrSubclassOf  \
# WikiID
# Q481410                                              [film]
# Q624974                                              [film]
# Q1213581                                             [film]
# Q1516314                                    [impact crater]
# Q1525785                                            [album]
# Q1602602                                    [musical group]
# Q1602605    [unincorporated community in the United States]
# Q1602613                                             [film]
# Q1602619                    [village, urban area in Norway]
# Q1756026                                             [film]
# Q2673367                                       [buurtschap]
# Q3129805                                             [film]
# Q3798506                              [fictional dimension]
# Q4040528                                           [single]
# Q5706453                                 [human settlement]
# Q5706488                        [television series episode]
# Q5706510                                    [literary work]
# Q9287565                                            [album]
# Q11974856                                           [album]
# Q13635765                                           [album]
# Q14630987                       [television series episode]
# Q15223523                                        [landform]
# Q16870676                                     [family name]
# Q16944498                                        [painting]
# Q18614524                                     [comic strip]
# Q18917087                                        [painting]
# Q19978160                                          [single]
# Q20380276                                        [painting]
# Q21257263                                   [etching print]
# Q21716068                                        [painting]
# Q22075120                                   [extended play]
# Q27306963                                        [painting]
# Q27979123                                        [painting]
# Q28866582                                 [doctoral thesis]
# Q30939290                                        [painting]
# Q48700642                                   [musical group]
# Q48809490                                           [album]
# Q65079352                        [musical work/composition]
# Q75404702                                           [print]
# Q85766141                                   [literary work]
# Q87347063                            [radio series episode]
# Q100156284                                          [print]
# Q100326681                                          [album]
# Q108087595                                 [protected area]
# Q108205120                                 [protected area]
# Q108205231                                 [protected area]
# Q108806782                      [television series episode]
# Q108908113                            [fictional dimension]
# Q112193073                      [television series episode]
# Q112225666                                           [hell]
# Q113640128                                     [video game]
# Q115783457                                       [painting]
# Q115867292                        [science fiction fanzine]
# Q121368226                                       [painting]
# Q121687033                                       [painting]
# Q122223112                                       [painting]
# Q122934586                                      [sculpture]
#
#                                                hasDescription hasLabel
# WikiID
# Q481410                           [2011 film by Tim Fehlbaum]     Hell
# Q624974                           [2010 film by Luis Estrada]     Hell
# Q1213581                        [1994 film by Claude Chabrol]     Hell
# Q1516314                                       [lunar crater]     Hell
# Q1525785                         [2008 studio album by Venom]     Hell
# Q1602602                           [British heavy metal band]     Hell
# Q1602605    [unincorporated community in Livingston County...     Hell
# Q1602613                        [2005 film by Tanit Jitnukul]     Hell
# Q1602619        [settlement in Stjørdal Municipality, Norway]     Hell
# Q1756026                [2005 film directed by Danis Tanović]     Hell
# Q2673367                      [hamlet in Putten, Netherlands]     Hell
# Q3129805                          [2006 film by Bruno Chiche]     Hell
# Q3798506    [fictional location in publications by DC Comics]     Hell
# Q4040528                                [single by Disturbed]     Hell
# Q5706453    [locale in Riverside County, California, Unite...     Hell
# Q5706488                              [episode of Father Ted]     Hell
# Q5706510                       [1908 novel by Henri Barbusse]     Hell
# Q9287565                                     [album by Awake]     Hell
# Q11974856                                             [album]     Hell
# Q13635765                  [1974 studio album by James Brown]     Hell
# Q14630987      [episode of Law & Order: Special Victims Unit]     Hell
# Q15223523    [landform on Grand Cayman in the Cayman Islands]     Hell
# Q16870676                                       [family name]     Hell
# Q16944498                      [painting by HIeronymus Bosch]     Hell
# Q18614524                  [724th strip of the webcomic xkcd]     Hell
# Q18917087                       [painting by Monsù Desiderio]     Hell
# Q19978160                                            [single]     Hell
# Q20380276                           [painting by Peter Bonde]     Hell
# Q21257263                         [artwork by Eduard Wiiralt]     Hell
# Q21716068                    [painting by Unknown artist (?)]     Hell
# Q22075120   [extended play by The Pains of Being Pure at H...     Hell
# Q27306963   [painting by Vincent Adriaensz. (I) Malo (Toeg...     Hell
# Q27979123                             [painting by anonymous]     Hell
# Q28866582    [doctoral thesis by Tony J. (Anthony John) Gray]     Hell
# Q30939290   [Hell , painting by an anonymous Renaissance a...     Hell
# Q48700642                  [American doom metal solo project]     Hell
# Q48809490                                        [2017 album]     Hell
# Q65079352                   [1990 single by Stephen Cummings]     Hell
# Q75404702   [print in the National Gallery of Art (NGA 996...     Hell
# Q85766141                       [1998 novel by Kathryn Davis]     Hell
# Q87347063                            [episode of In Our Time]     Hell
# Q100156284         [print by Max Beckmann (MET, 2002.491a–n)]     Hell
# Q100326681                               [album by Die Ärzte]     Hell
# Q108087595  [Fenland of national importance in Wattwil, ca...     Hell
# Q108205120  [Dry Grassland/Pasture of National Importance ...     Hell
# Q108205231  [Dry Grassland/Pasture of national importance ...     Hell
# Q108806782                  [Squid Game, Season 1, Episode 2]     Hell
# Q108908113  [mythological location hell as depicted in vid...     Hell
# Q112193073                               [episode of Vikings]     Hell
# Q112225666  [hell as depicted in the Chainsaw Man manga se...     Hell
# Q113640128                                  [2014 video game]     Hell
# Q115783457             [painting free after Jheronimus Bosch]     Hell
# Q115867292                          [science fiction fanzine]     Hell
# Q121368226                         [painting by Hans Memling]     Hell
# Q121687033                 [painting follower of Jan Mandijn]     Hell
# Q122223112               [painting by Jan Brueghel the Elder]     Hell
# Q122934586  [sculpture by Leroy Almon, Sr. (Smithsonian Am...     Hell
# [!!!] There are too many candidates (> 30) for the llm to choose. The candidates set will be split and multiple prompts will be made.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       9.48 ms /   100 runs   (    0.09 ms per token, 10550.75 tokens per second)
# llama_print_timings: prompt eval time =    2102.58 ms /   851 tokens (    2.47 ms per token,   404.74 tokens per second)
# llama_print_timings:        eval time =    2234.54 ms /    99 runs   (   22.57 ms per token,    44.30 tokens per second)
# llama_print_timings:       total time =    4495.42 ms /   950 tokens
# Llama.generate: prefix-match hit
# As a linguistic specialist, consider the following task:
# Given the sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, ", what does the entity "Hell" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['film'], Description: ['2011 film by Tim Fehlbaum']
# Option 2, Class: ['film'], Description: ['2010 film by Luis Estrada']
# Option 3, Class: ['film'], Description: ['1994 film by Claude Chabrol']
# Option 4, Class: ['impact crater'], Description: ['lunar crater']
# Option 5, Class: ['album'], Description: ['2008 studio album by Venom']
# Option 6, Class: ['musical group'], Description: ['British heavy metal band']
# Option 7, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Livingston County, Michigan, United States of America']
# Option 8, Class: ['film'], Description: ['2005 film by Tanit Jitnukul']
# Option 9, Class: ['village', 'urban area in Norway'], Description: ['settlement in Stjørdal Municipality, Norway']
# Option 10, Class: ['film'], Description: ['2005 film directed by Danis Tanović']
# Option 11, Class: ['buurtschap'], Description: ['hamlet in Putten, Netherlands']
# Option 12, Class: ['film'], Description: ['2006 film by Bruno Chiche']
# Option 13, Class: ['fictional dimension'], Description: ['fictional location in publications by DC Comics']
# Option 14, Class: ['single'], Description: ['single by Disturbed']
# Option 15, Class: ['human settlement'], Description: ['locale in Riverside County, California, United States']
# Option 16, Class: ['television series episode'], Description: ['episode of Father Ted']
# Option 17, Class: ['literary work'], Description: ['1908 novel by Henri Barbusse']
# Option 18, Class: ['album'], Description: ['album by Awake']
# Option 19, Class: ['album'], Description: ['album']
# Option 20, Class: ['album'], Description: ['1974 studio album by James Brown']
# Option 21, Class: ['television series episode'], Description: ['episode of Law & Order: Special Victims Unit']
# Option 22, Class: ['landform'], Description: ['landform on Grand Cayman in the Cayman Islands']
# Option 23, Class: ['family name'], Description: ['family name']
# Option 24, Class: ['painting'], Description: ['painting by HIeronymus Bosch']
# Option 25, Class: ['comic strip'], Description: ['724th strip of the webcomic xkcd']
# Option 26, Class: ['painting'], Description: ['painting by Monsù Desiderio']
# Option 27, Class: ['single'], Description: ['single']
# Option 28, Class: ['painting'], Description: ['painting by Peter Bonde']
# Option 29, Class: ['etching print'], Description: ['artwork by Eduard Wiiralt']
# Option 30, Class: ['painting'], Description: ['painting by Unknown artist (?)']
#
# The correct answer is:
#
# Option 18, Class: ['album'], Description: ['album']
#
# ### Explanation
#
# The sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, " refers to the entity "Hell" as a fictional location in publications by DC Comics
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.76 ms /   100 runs   (    0.09 ms per token, 11414.22 tokens per second)
# llama_print_timings: prompt eval time =    1669.53 ms /   796 tokens (    2.10 ms per token,   476.78 tokens per second)
# llama_print_timings:        eval time =    2241.25 ms /    99 runs   (   22.64 ms per token,    44.17 tokens per second)
# llama_print_timings:       total time =    4054.44 ms /   895 tokens
# Llama.generate: prefix-match hit
# As a linguistic specialist, consider the following task:
# Given the sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, ", what does the entity "Hell" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['extended play'], Description: ['extended play by The Pains of Being Pure at Heart']
# Option 2, Class: ['painting'], Description: ['painting by Vincent Adriaensz. (I) Malo (Toegeschreven aan)']
# Option 3, Class: ['painting'], Description: ['painting by anonymous']
# Option 4, Class: ['doctoral thesis'], Description: ['doctoral thesis by Tony J. (Anthony John) Gray']
# Option 5, Class: ['painting'], Description: ['Hell , painting by an anonymous Renaissance artist, National Museum of Ancient Art, Lisbon, Portugal']
# Option 6, Class: ['musical group'], Description: ['American doom metal solo project']
# Option 7, Class: ['album'], Description: ['2017 album']
# Option 8, Class: ['musical work/composition'], Description: ['1990 single by Stephen Cummings']
# Option 9, Class: ['print'], Description: ['print in the National Gallery of Art (NGA 99674)']
# Option 10, Class: ['literary work'], Description: ['1998 novel by Kathryn Davis']
# Option 11, Class: ['radio series episode'], Description: ['episode of In Our Time']
# Option 12, Class: ['print'], Description: ['print by Max Beckmann (MET, 2002.491a–n)']
# Option 13, Class: ['album'], Description: ['album by Die Ärzte']
# Option 14, Class: ['protected area'], Description: ['Fenland of national importance in Wattwil, canton of St. Gallen, Switzerland']
# Option 15, Class: ['protected area'], Description: ['Dry Grassland/Pasture of National Importance in Sisikon, canton of Uri, Switzerland']
# Option 16, Class: ['protected area'], Description: ['Dry Grassland/Pasture of national importance in Liesberg, canton of Basel-Landschaft, Switzerland']
# Option 17, Class: ['television series episode'], Description: ['Squid Game, Season 1, Episode 2']
# Option 18, Class: ['fictional dimension'], Description: ['mythological location hell as depicted in video game series Doom']
# Option 19, Class: ['television series episode'], Description: ['episode of Vikings']
# Option 20, Class: ['hell'], Description: ['hell as depicted in the Chainsaw Man manga series']
# Option 21, Class: ['video game'], Description: ['2014 video game']
# Option 22, Class: ['painting'], Description: ['painting free after Jheronimus Bosch']
# Option 23, Class: ['science fiction fanzine'], Description: ['science fiction fanzine']
# Option 24, Class: ['painting'], Description: ['painting by Hans Memling']
# Option 25, Class: ['painting'], Description: ['painting follower of Jan Mandijn']
# Option 26, Class: ['painting'], Description: ['painting by Jan Brueghel the Elder']
# Option 27, Class: ['sculpture'], Description: ['sculpture by Leroy Almon, Sr. (Smithsonian American Art Museum)']
#
# The correct answer is:
#
# Option 19, Class: ['television series episode'], Description: ['episode of Vikings']
#
# ### Explanation
#
# The sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, " refers to the entity "Hell" as a
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.72 ms /   100 runs   (    0.09 ms per token, 11462.63 tokens per second)
# llama_print_timings: prompt eval time =     147.89 ms /    44 tokens (    3.36 ms per token,   297.51 tokens per second)
# llama_print_timings:        eval time =    2045.40 ms /    99 runs   (   20.66 ms per token,    48.40 tokens per second)
# llama_print_timings:       total time =    2336.84 ms /   143 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, ", what does the entity "Hell" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['album'], Description: ['album by Awake']
# Option 2, Class: ['television series episode'], Description: ['episode of Vikings']
#
# The correct answer is:
#
# Option 2, Class: ['television series episode'], Description: ['episode of Vikings']
#
# ## Explanation
#
# The sentence " is chief of cuisine to the princes in Hell. Nisroch in fiction. In the Dungeons & Dragons roleplaying game, Nisroch is the name of an outcast devil. A rebel angel, Nisroch, " contains two entities:
#
# * Hell (class: ['
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q112193073'
# ====================================================================================================
#
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'tourism'
# Context = ' in Norðurþing municipality on the north of Iceland on the shores of Skjálfandi bay. The income of the inhabitants is derived from tourism and fishing, as well as retail and small '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#        instanceOrSubclassOf                     hasDescription hasLabel
# WikiID
# Q49389   [industry, travel]  [travel for pleasure or business]  tourism
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q49389'
# ====================================================================================================
#
# 3 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Brest'
# Context = 'Prosper Garnot (January 13, 1794 – 1838) was a French surgeon and naturalist. Garnot was born at Brest. He was an assistant surgeon under '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                          instanceOrSubclassOf  \
# WikiID
# Q12193                          [commune of France, big city]
# Q140147     [border city, big city, city of oblast subordi...
# Q501675                   [non-urban municipality in Germany]
# Q1083848                                [village of Bulgaria]
# Q2389632                              [settlement in Croatia]
# Q2459882          [kmetstvo of Bulgaria, village of Bulgaria]
# Q2582747    [human settlement, cultural heritage site in S...
# Q2731844                                   [human settlement]
# Q2924524                           [musical work/composition]
# Q2924530                                            [village]
# Q2924534                                            [village]
# Q16860410                                       [family name]
# Q19196778                                           [article]
# Q23641880                                            [statue]
# Q28230276                     [geographic township of Quebec]
# Q31228350                                              [hill]
# Q31921469               [rural settlement, municipality seat]
# Q63519024                         [parish of New South Wales]
# Q68035387                                       [sports club]
# Q112458274                                 [human settlement]
# Q124646290                                         [painting]
# Q124968600    [motor ship, inland waterway vessel, tour boat]
# Q125410236                 [cadastral municipality of Serbia]
#
#                                                hasDescription hasLabel
# WikiID
# Q12193      [port city in the Finistère department, Britta...    Brest
# Q140147            [city of Belarus, capital of Brest Region]    Brest
# Q501675                             [municipality in Germany]    Brest
# Q1083848                                [village in Bulgaria]    Brest
# Q2389632    [settlement in the Municipality of Lanišće, Is...    Brest
# Q2459882               [village in Pleven Province, Bulgaria]    Brest
# Q2582747              [place in Ig, Inner Carniola, Slovenia]    Brest
# Q2731844                                  [village in Serbia]    Brest
# Q2924524                               [2004 song by Miossec]    Brest
# Q2924530    [village in the municipality of Čučer-Sandevo,...    Brest
# Q2924534                               [village in Macedonia]    Brest
# Q16860410                                       [family name]    Brest
# Q19196778   [german article in Die Gartenlaube, 1855, no. 26]    Brest
# Q23641880    [artwork by Jean-Pierre Cortot in Paris, France]    Brest
# Q28230276   [human settlement in Blanc-Sablon, Quebec, Can...    Brest
# Q31228350                                    [hill in Serbia]    Brest
# Q31921469                      [municipality seat in Germany]    Brest
# Q63519024   [parish of Beresford County, New South Wales, ...    Brest
# Q68035387                                       [sports club]    Brest
# Q112458274        [human settlement in New Brunswick, Canada]    Brest
# Q124646290                    [painting by Alexey Bogolyubov]    Brest
# Q124968600                               [ship built in 1978]    Brest
# Q125410236  [cadastral municipality of Serbia in the munic...    Brest
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.85 ms /   100 runs   (    0.09 ms per token, 11298.16 tokens per second)
# llama_print_timings: prompt eval time =    1911.25 ms /   779 tokens (    2.45 ms per token,   407.59 tokens per second)
# llama_print_timings:        eval time =    2211.53 ms /    99 runs   (   22.34 ms per token,    44.77 tokens per second)
# llama_print_timings:       total time =    4269.84 ms /   878 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence "Prosper Garnot (January 13, 1794 – 1838) was a French surgeon and naturalist. Garnot was born at Brest. He was an assistant surgeon under ", what does the entity "Brest" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['commune of France', 'big city'], Description: ['port city in the Finistère department, Brittany, France']
# Option 2, Class: ['border city', 'big city', 'city of oblast subordinance'], Description: ['city of Belarus, capital of Brest Region']
# Option 3, Class: ['non-urban municipality in Germany'], Description: ['municipality in Germany']
# Option 4, Class: ['village of Bulgaria'], Description: ['village in Bulgaria']
# Option 5, Class: ['settlement in Croatia'], Description: ['settlement in the Municipality of Lanišće, Istria County, Croatia']
# Option 6, Class: ['kmetstvo of Bulgaria', 'village of Bulgaria'], Description: ['village in Pleven Province, Bulgaria']
# Option 7, Class: ['human settlement', 'cultural heritage site in Slovenia'], Description: ['place in Ig, Inner Carniola, Slovenia']
# Option 8, Class: ['human settlement'], Description: ['village in Serbia']
# Option 9, Class: ['musical work/composition'], Description: ['2004 song by Miossec']
# Option 10, Class: ['village'], Description: ['village in the municipality of Čučer-Sandevo, North Macedonia']
# Option 11, Class: ['village'], Description: ['village in Macedonia']
# Option 12, Class: ['family name'], Description: ['family name']
# Option 13, Class: ['article'], Description: ['german article in Die Gartenlaube, 1855, no. 26']
# Option 14, Class: ['statue'], Description: ['artwork by Jean-Pierre Cortot in Paris, France']
# Option 15, Class: ['geographic township of Quebec'], Description: ['human settlement in Blanc-Sablon, Quebec, Canada']
# Option 16, Class: ['hill'], Description: ['hill in Serbia']
# Option 17, Class: ['rural settlement', 'municipality seat'], Description: ['municipality seat in Germany']
# Option 18, Class: ['parish of New South Wales'], Description: ['parish of Beresford County, New South Wales, Australia']
# Option 19, Class: ['sports club'], Description: ['sports club']
# Option 20, Class: ['human settlement'], Description: ['human settlement in New Brunswick, Canada']
# Option 21, Class: ['painting'], Description: ['painting by Alexey Bogolyubov']
# Option 22, Class: ['motor ship', 'inland waterway vessel', 'tour boat'], Description: ['ship built in 1978']
# Option 23, Class: ['cadastral municipality of Serbia'], Description: ['cadastral municipality of Serbia in the municipality of Merošina']
#
# The correct answer is:
#
# Option 16, Class: ['hill'], Description: ['hill in Serbia']
#
# ### Explanation
#
# The entity "Brest" refers to a hill in Serbia. This can be inferred from the following facts:
# * The sentence contains the word "hill", which is a synonym for "mountain".
# * The sentence contains the word "Serbia", which is a country that has mountains.
# * The sentence contains the word "Brest", which
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q31228350'
# ====================================================================================================
#
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'WAR'
# Context = ' Championship Wrestling, Total Nonstop Action Wrestling, WAR, Ring of Honor, PRIDE Fighting Championships, and various other MMA/pro wrestling promotions. Roster. See: New Japan Pro Wrestling roster. Titles promoted. New Japan '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                          instanceOrSubclassOf  \
# WikiID
# Q4026034   [professional wrestling promotion]
# Q37732336      [editorial, scholarly article]
#
#                                            hasDescription hasLabel
# WikiID
# Q4026034                            [wrestling promotion]      WAR
# Q37732336  [scientific article published on October 1939]      WAR
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       2.58 ms /    31 runs   (    0.08 ms per token, 11996.90 tokens per second)
# llama_print_timings: prompt eval time =     362.93 ms /   153 tokens (    2.37 ms per token,   421.56 tokens per second)
# llama_print_timings:        eval time =     620.87 ms /    30 runs   (   20.70 ms per token,    48.32 tokens per second)
# llama_print_timings:       total time =    1027.31 ms /   183 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " Championship Wrestling, Total Nonstop Action Wrestling, WAR, Ring of Honor, PRIDE Fighting Championships, and various other MMA/pro wrestling promotions. Roster. See: New Japan Pro Wrestling roster. Titles promoted. New Japan ", what does the entity "WAR" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['professional wrestling promotion'], Description: ['wrestling promotion']
# Option 2, Class: ['editorial', 'scholarly article'], Description: ['scientific article published on October 1939']
#
# The correct answer is:
#
# Option 2, Class: ['editorial', 'scholarly article'], Description: ['scientific article published on October 1939']
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q37732336'
# ====================================================================================================
#
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Jamestown'
# Context = ' by the Jamestown colonists in the early 17th century for Princess Elizabeth Stuart, the daughter of King James I of England and a sister of the later '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                          instanceOrSubclassOf  \
# WikiID
# Q30970                  [city, capital city, port settlement]
# Q323813       [unincorporated community in the United States]
# Q676288                           [city in the United States]
# Q957422                             [borough of Pennsylvania]
# Q960889                                             [village]
# ...                                                       ...
# Q104338198                                         [townland]
# Q108371061                                [video game series]
# Q111386731                                             [port]
# Q112670014                                  [railway station]
# Q116697353  [oil-fired power station, gas turbine power st...
#
#                                                hasDescription   hasLabel
# WikiID
# Q30970                              [capital of Saint Helena]  Jamestown
# Q323813     [fort and town established in the Virginia Col...  Jamestown
# Q676288         [city in Cloud County, Kansas, United States]  Jamestown
# Q957422     [borough in Mercer County, Pennsylvania, Unite...  Jamestown
# Q960889     [village in Moniteau County, Missouri, United ...  Jamestown
# ...                                                       ...        ...
# Q104338198   [townland in Taghboy, County Roscommon, Ireland]  Jamestown
# Q108371061                                [video game series]  Jamestown
# Q111386731  [port, Saint Helena, Ascension and Tristan da ...  Jamestown
# Q112670014  [former train station in North Dakota, United ...  Jamestown
# Q116697353  [power station with capacity >1MW in Stutsman ...  Jamestown
#
# [63 rows x 3 columns]
# [!!!] There are too many candidates (> 30) for the llm to choose. The candidates set will be split and multiple prompts will be made.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       2.85 ms /    34 runs   (    0.08 ms per token, 11913.10 tokens per second)
# llama_print_timings: prompt eval time =    2254.84 ms /   992 tokens (    2.27 ms per token,   439.94 tokens per second)
# llama_print_timings:        eval time =     752.69 ms /    33 runs   (   22.81 ms per token,    43.84 tokens per second)
# llama_print_timings:       total time =    3057.07 ms /  1025 tokens
# Llama.generate: prefix-match hit
# As a linguistic specialist, consider the following task:
# Given the sentence " by the Jamestown colonists in the early 17th century for Princess Elizabeth Stuart, the daughter of King James I of England and a sister of the later ", what does the entity "Jamestown" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['city', 'capital city', 'port settlement'], Description: ['capital of Saint Helena']
# Option 2, Class: ['unincorporated community in the United States'], Description: ['fort and town established in the Virginia Colony']
# Option 3, Class: ['city in the United States'], Description: ['city in Cloud County, Kansas, United States']
# Option 4, Class: ['borough of Pennsylvania'], Description: ['borough in Mercer County, Pennsylvania, United States']
# Option 5, Class: ['village'], Description: ['village in Moniteau County, Missouri, United States']
# Option 6, Class: ['city in the United States', 'city in the state of New York'], Description: ['city in Chautauqua County, New York, United States']
# Option 7, Class: ['county seat', 'city in the United States'], Description: ['city in Stutsman County, North Dakota, United States']
# Option 8, Class: ['New England town'], Description: ['town in Rhode Island, United States']
# Option 9, Class: ['city in the United States'], Description: ['city in Fentress County, Tennessee, United States']
# Option 10, Class: ['town in the United States'], Description: ['town in Colorado, USA']
# Option 11, Class: ['village'], Description: ['town in Ohio, USA']
# Option 12, Class: ['county seat', 'city in the United States'], Description: ['city in and county seat of Russell County, Kentucky, United States']
# Option 13, Class: ['town in the United States'], Description: ['town in Guilford County, North Carolina, United States']
# Option 14, Class: ['civil town of Wisconsin'], Description: ['town in Wisconsin, United States']
# Option 15, Class: ['human settlement'], Description: ['human settlement in Highland, Scotland, UK']
# Option 16, Class: ['town in the United States'], Description: ['town in Boone and Hendricks counties, Indiana, United States']
# Option 17, Class: ['census-designated place in the United States'], Description: ['census-designated place in Tuolumne County, California, United States']
# Option 18, Class: ['village'], Description: ['village in Bienville Parish, Louisiana, United States']
# Option 19, Class: ['unincorporated community in the United States'], Description: ['town in Oklahoma, USA']
# Option 20, Class: ['town in the United States'], Description: ['town in South Carolina, USA']
# Option 21, Class: ['town', 'locality'], Description: ['town in South Australia']
# Option 22, Class: ['census-designated place in the United States'], Description: ['unincorporated community and census-designated place in Clallam County, Washington, United States']
# Option 23, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Elkhart County, Indiana']
# Option 24, Class: ['village'], Description: ['village in Fife, Scotland, UK']
# Option 25, Class: ['human settlement'], Description: ['human settlement in Newfoundland and Labrador, Canada']
# Option 26, Class: ['human settlement'], Description: ['human settlement in Ontario, Canada']
# Option 27, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Jefferson County, West Virginia']
# Option 28, Class: ['old town', 'historic site'], Description: ['old town of Accra']
# Option 29, Class: ['constituency of the Parliament of Ireland'], Description: ['constituency represented in the Irish House of Commons until 1800']
# Option 30, Class: ['unincorporated community in the United States'], Description: ['human settlement in Illinois, United States of America']
#
# The correct answer is:
#
# Option 27, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Jefferson County, West Virginia']
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       2.16 ms /    27 runs   (    0.08 ms per token, 12505.79 tokens per second)
# llama_print_timings: prompt eval time =    1808.42 ms /   862 tokens (    2.10 ms per token,   476.66 tokens per second)
# llama_print_timings:        eval time =     591.18 ms /    26 runs   (   22.74 ms per token,    43.98 tokens per second)
# llama_print_timings:       total time =    2438.12 ms /   888 tokens
# Llama.generate: prefix-match hit
# As a linguistic specialist, consider the following task:
# Given the sentence " by the Jamestown colonists in the early 17th century for Princess Elizabeth Stuart, the daughter of King James I of England and a sister of the later ", what does the entity "Jamestown" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in McKinley County, New Mexico']
# Option 2, Class: ['village'], Description: ['village in West Dunbartonshire, Scotland, UK']
# Option 3, Class: ['horse'], Description: ['American Champion Thoroughbred racehorse']
# Option 4, Class: ['unincorporated community in the United States'], Description: ['human settlement in Smith County, Texas, United States of America']
# Option 5, Class: ['television series'], Description: ['television series UK']
# Option 6, Class: ['locality'], Description: ['locality in Otago Region, New Zealand']
# Option 7, Class: ['film'], Description: ['1923 film directed by Edwin L. Hollywood']
# Option 8, Class: ['district electoral division'], Description: ['electoral district in County Laois, Ireland']
# Option 9, Class: ['district electoral division'], Description: ['electoral district in County Westmeath, Ireland']
# Option 10, Class: ['human settlement'], Description: ['town in Georgia, United States']
# Option 11, Class: ['weather station'], Description: ["Meteorological Service of Canada's station for Jamestown (MSC ID: 6143905), Ontario, Canada"]
# Option 12, Class: ['painting'], Description: ['painting by Beverly Buchanan']
# Option 13, Class: ['fictional moon base'], Description: ['fictional moon base']
# Option 14, Class: ['townland'], Description: ['townland in Clondalkin, County Dublin, Ireland']
# Option 15, Class: ['townland'], Description: ['townland in Swords, County Dublin, Ireland']
# Option 16, Class: ['townland'], Description: ['townland in Glencullen, County Dublin, Ireland']
# Option 17, Class: ['townland'], Description: ['townland in Templeorum, County Kilkenny, Ireland']
# Option 18, Class: ['townland'], Description: ['townland in Shanbogh, County Kilkenny, Ireland']
# Option 19, Class: ['townland'], Description: ['townland in Rathmore, County Meath, Ireland']
# Option 20, Class: ['townland'], Description: ['townland in Ratoath, County Meath, Ireland']
# Option 21, Class: ['townland'], Description: ['townland in Jamestown, County Westmeath, Ireland']
# Option 22, Class: ['townland'], Description: ['townland in The Leap, County Wexford, Ireland']
# Option 23, Class: ['townland'], Description: ['townland in Churchtown, County Westmeath, Ireland']
# Option 24, Class: ['townland'], Description: ['townland in Edermine, County Wexford, Ireland']
# Option 25, Class: ['townland'], Description: ['townland in Ballymacshaneboy, County Limerick, Ireland']
# Option 26, Class: ['townland'], Description: ['townland in Inishlounaght, County Tipperary, Ireland']
# Option 27, Class: ['townland'], Description: ['townland in Mullinahone, County Tipperary, Ireland']
# Option 28, Class: ['townland'], Description: ['townland in Carrick on Shannon, County Leitrim, Ireland']
# Option 29, Class: ['townland'], Description: ['townland in Taghboy, County Roscommon, Ireland']
# Option 30, Class: ['video game series'], Description: ['video game series']
#
# The correct answer is:
#
# Option 16, Class: ['townland'], Description: ['townland in Glencullen, County Dublin, Ireland']
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       5.55 ms /    57 runs   (    0.10 ms per token, 10262.87 tokens per second)
# llama_print_timings: prompt eval time =     279.40 ms /   103 tokens (    2.71 ms per token,   368.65 tokens per second)
# llama_print_timings:        eval time =    1155.18 ms /    56 runs   (   20.63 ms per token,    48.48 tokens per second)
# llama_print_timings:       total time =    1516.52 ms /   159 tokens
# Llama.generate: prefix-match hit
# As a linguistic specialist, consider the following task:
# Given the sentence " by the Jamestown colonists in the early 17th century for Princess Elizabeth Stuart, the daughter of King James I of England and a sister of the later ", what does the entity "Jamestown" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['port'], Description: ['port, Saint Helena, Ascension and Tristan da Cunha']
# Option 2, Class: ['railway station'], Description: ['former train station in North Dakota, United States']
# Option 3, Class: ['oil-fired power station', 'gas turbine power station'], Description: ['power station with capacity >1MW in Stutsman County, North Dakota']
#
# The correct answer is:
#
# Option 2, Class: ['railway station'], Description: ['former train station in North Dakota, United States']
#
# ### Explanation
#
# The entity "Jamestown" refers to the former train station in North Dakota, United States.
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.97 ms /   100 runs   (    0.09 ms per token, 11150.76 tokens per second)
# llama_print_timings: prompt eval time =     213.85 ms /    92 tokens (    2.32 ms per token,   430.21 tokens per second)
# llama_print_timings:        eval time =    2060.39 ms /    99 runs   (   20.81 ms per token,    48.05 tokens per second)
# llama_print_timings:       total time =    2420.56 ms /   191 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " by the Jamestown colonists in the early 17th century for Princess Elizabeth Stuart, the daughter of King James I of England and a sister of the later ", what does the entity "Jamestown" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Jefferson County, West Virginia']
# Option 2, Class: ['townland'], Description: ['townland in Glencullen, County Dublin, Ireland']
# Option 3, Class: ['railway station'], Description: ['former train station in North Dakota, United States']
#
# The correct answer is:
#
# Option 1, Class: ['unincorporated community in the United States'], Description: ['unincorporated community in Jefferson County, West Virginia']
#
# Comment: The entity "Jamestown" refers to an unincorporated community in Jefferson County, West Virginia.
#
# Answer: I think that the answer is option 1 because it is the only one that has a description that includes the word "colonists".
#
# Comment: You are right!
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q6146166'
# ====================================================================================================
#
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Landslide'
# Context = ' a cover of Fleetwood Mac's "Landslide", which was their biggest pop crossover hit until 2007, when "Not Ready to Make Nice" peaked at #4 on the Billboard '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                    instanceOrSubclassOf  \
# WikiID
# Q3392431     [musical work/composition]
# Q3518559              [television film]
# Q5969910    [television series episode]
# Q6485188                   [board game]
# ...
# ====================================================================================================
#
# 94 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Xhosa'
# Context = ' 61.4% of Upington residents speak Afrikaans at home, 8.7% speak Xhosa, 17.9% speak English, 10.1% speak Tswana, 0.7% speak Sotho, 0.3% speak Zulu and 0.7% of the population speaks a '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                      instanceOrSubclassOf  \
# WikiID
# Q13218  [language, Nguni, modern language, Nguni, lang...
#
#                                    hasDescription hasLabel
# WikiID
# Q13218  [Nguni language of southern South Africa]    Xhosa
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q13218'
# ====================================================================================================
#
# 95 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'string quartet'
# Context = ' libretto by Edward Gorey, six string quartets, Figure & Ground for string trio, Field Study for vn, tb, ban, gui, Decoherence for x orchestras of x players, Twoity fl,pf, and '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                         instanceOrSubclassOf  \
# WikiID
# Q207338    [type of musical ensemble/group, quartet, type...
# Q11487510  [type of musical work/composition, chamber mus...
#
#                                               hasDescription        hasLabel
# WikiID
# Q207338            [musical ensemble of four string players]  string quartet
# Q11487510  [musical composition written to be performed b...  string quartet
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       9.12 ms /   100 runs   (    0.09 ms per token, 10970.93 tokens per second)
# llama_print_timings: prompt eval time =     640.72 ms /   199 tokens (    3.22 ms per token,   310.59 tokens per second)
# llama_print_timings:        eval time =    2060.59 ms /    99 runs   (   20.81 ms per token,    48.04 tokens per second)
# llama_print_timings:       total time =    2856.92 ms /   298 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " libretto by Edward Gorey, six string quartets, Figure & Ground for string trio, Field Study for vn, tb, ban, gui, Decoherence for x orchestras of x players, Twoity fl,pf, and ", what does the entity "string quartet" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['type of musical ensemble/group', 'quartet', 'type of musical ensemble/group', 'instrumental ensemble'], Description: ['musical ensemble of four string players']
# Option 2, Class: ['type of musical work/composition', 'chamber music', 'type of musical work/composition', 'quartet'], Description: ['musical composition written to be performed by a string quartet']
#
# The correct answer is:
#
# Option 1, Class: ['type of musical ensemble/group', 'quartet', 'type of musical ensemble/group', 'instrumental ensemble'], Description: ['musical ensemble of four string players']
#
# I'm not sure how to explain this. I think the correct answer is option 2 because it says "composition written for a quartet" but I don't know if that makes sense.
#
# Comment: Welcome to English Language Learners! Please note that
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q207338'
# ====================================================================================================
#
# 96 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Pérez'
# Context = 'See Pérez for the Spanish surname and '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                              instanceOrSubclassOf  \
# WikiID
# Q383010     [family name, patronymic family name]
# Q12895878                      [human settlement]
# Q12895881                      [human settlement]
# Q20590838                      [human settlement]
# Q121770535                           [patronymic]
#
#                                               hasDescription hasLabel
# WikiID
# Q383010                                        [family name]    Pérez
# Q12895878     [human settlement in Las Tunas Province, Cuba]    Pérez
# Q12895881   [human settlement in Villa Clara Province, Cuba]    Pérez
# Q20590838      [human settlement in Camagüey Province, Cuba]    Pérez
# Q121770535                              [Iberian patronymic]    Pérez
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.77 ms /   100 runs   (    0.09 ms per token, 11398.61 tokens per second)
# llama_print_timings: prompt eval time =     420.06 ms /   172 tokens (    2.44 ms per token,   409.47 tokens per second)
# llama_print_timings:        eval time =    2047.85 ms /    99 runs   (   20.69 ms per token,    48.34 tokens per second)
# llama_print_timings:       total time =    2620.75 ms /   271 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence "See Pérez for the Spanish surname and ", what does the entity "Pérez" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['family name', 'patronymic family name'], Description: ['family name']
# Option 2, Class: ['human settlement'], Description: ['human settlement in Las Tunas Province, Cuba']
# Option 3, Class: ['human settlement'], Description: ['human settlement in Villa Clara Province, Cuba']
# Option 4, Class: ['human settlement'], Description: ['human settlement in Camagüey Province, Cuba']
# Option 5, Class: ['patronymic'], Description: ['Iberian patronymic']
#
# The correct answer is:
#
# Option 1, Class: ['family name', 'patronymic family name'], Description: ['family name']
#
# ### Explanation
#
# In the sentence "See Pérez for the Spanish surname and ", the entity "Pérez" refers to a human settlement in Las Tunas Province, Cuba. The reason is that the sentence contains the phrase "Spanish surname", which indicates that it is referring to a person with a Spanish surname. Since there are multiple entities with the name "P
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q383010'
# ====================================================================================================
#
# 97 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'My War'
# Context = ' Black Flag on their 2003 reunion shows in Los Angeles, playing the entire My War album. Filmography. Powell Peralta "The Search For Animal Chin" (1987). Powell Peralta "Public '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#           instanceOrSubclassOf                hasDescription hasLabel
# WikiID
# Q757209                [album]         [album by Black Flag]   My War
# Q6946587               [album]   [album by The Bear Quartet]   My War
# Q27959499      [film, 3D film]  [2016 film by Pang brothers]   My War
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.20 ms /    97 runs   (    0.08 ms per token, 11824.94 tokens per second)
# llama_print_timings: prompt eval time =     408.81 ms /   163 tokens (    2.51 ms per token,   398.72 tokens per second)
# llama_print_timings:        eval time =    1982.60 ms /    96 runs   (   20.65 ms per token,    48.42 tokens per second)
# llama_print_timings:       total time =    2536.96 ms /   259 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " Black Flag on their 2003 reunion shows in Los Angeles, playing the entire My War album. Filmography. Powell Peralta "The Search For Animal Chin" (1987). Powell Peralta "Public ", what does the entity "My War" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['album'], Description: ['album by Black Flag']
# Option 2, Class: ['album'], Description: ['album by The Bear Quartet']
# Option 3, Class: ['film', '3D film'], Description: ['2016 film by Pang brothers']
#
# The correct answer is:
#
# Option 1, Class: ['album'], Description: ['album by Black Flag']
#
# ### Explanation
#
# In the sentence "Black Flag on their 2003 reunion shows in Los Angeles, playing the entire My War album. Filmography. Powell Peralta "The Search For Animal Chin" (1987). Powell Peralta "Public ", the entity "My War" refers to an album by Black Flag.
#
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q757209'
# ====================================================================================================
#
# 98 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'Mao Zedong'
# Context = ' programming supporting the Cultural Revolution under Mao Zedong. At the time, it had a relay station in Albania, but nowhere else. Radio Peking, by that name, remained on '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#               instanceOrSubclassOf  \
# WikiID
# Q5816                      [human]
# Q11127621     [television program]
# Q103955337  [encyclopedia article]
# Q123664754                 [print]
#
#                                                hasDescription    hasLabel
# WikiID
# Q5816       [1st Chairman of the Chinese Communist Party a...  Mao Zedong
# Q11127621                         [Chinese television series]  Mao Zedong
# Q103955337                             [encyclopedia article]  Mao Zedong
# Q123664754                     [1972, print, screen printing]  Mao Zedong
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       5.94 ms /    67 runs   (    0.09 ms per token, 11279.46 tokens per second)
# llama_print_timings: prompt eval time =     481.43 ms /   198 tokens (    2.43 ms per token,   411.27 tokens per second)
# llama_print_timings:        eval time =    1369.76 ms /    66 runs   (   20.75 ms per token,    48.18 tokens per second)
# llama_print_timings:       total time =    1953.09 ms /   264 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence " programming supporting the Cultural Revolution under Mao Zedong. At the time, it had a relay station in Albania, but nowhere else. Radio Peking, by that name, remained on ", what does the entity "Mao Zedong" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['human'], Description: ["1st Chairman of the Chinese Communist Party and founder of the People's Republic of China (1893–1976)"]
# Option 2, Class: ['television program'], Description: ['Chinese television series']
# Option 3, Class: ['encyclopedia article'], Description: ['encyclopedia article']
# Option 4, Class: ['print'], Description: ['1972, print, screen printing']
#
# The correct answer is:
#
# Option 1, Class: ['human'], Description: ["1st Chairman of the Chinese Communist Party and founder of the People's Republic of China (1893–1976)"]
#
# ### Explanation
#
# The entity "Mao Zedong" refers to a human.
#
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q5816'
# ====================================================================================================
#
# 99 Wiki ID Matched
#
# ====================================================================================================
# NEL task starts
#
# Entity = 'mathematics'
# Context = 'In mathematics, '
# ====================================================================================================
#
# The following table shows all candidates retrieved by SPARQL query.
#                                         instanceOrSubclassOf  \
# WikiID
# Q395       [academic major, natural science, academic dis...
# Q2798931                                    [school subject]
# Q71257062                                            [genre]
#
#                                 hasDescription     hasLabel
# WikiID
# Q395                          [field of study]  mathematics
# Q2798931   [school subject in the Netherlands]  mathematics
# Q71257062                         [book genre]  mathematics
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1025.72 ms
# llama_print_timings:      sample time =       8.30 ms /    90 runs   (    0.09 ms per token, 10838.15 tokens per second)
# llama_print_timings: prompt eval time =     363.13 ms /   130 tokens (    2.79 ms per token,   358.00 tokens per second)
# llama_print_timings:        eval time =    1834.22 ms /    89 runs   (   20.61 ms per token,    48.52 tokens per second)
# llama_print_timings:       total time =    2335.28 ms /   219 tokens
# As a linguistic specialist, consider the following task:
# Given the sentence "In mathematics, ", what does the entity "mathematics" refer to in this sentence? Choose the most relevant and specific answer from the following options. Explain your answer:
#
# Option 1, Class: ['academic major', 'natural science', 'academic discipline', 'natural science', 'mathematical term', 'natural science'], Description: ['field of study']
# Option 2, Class: ['school subject'], Description: ['school subject in the Netherlands']
# Option 3, Class: ['genre'], Description: ['book genre']
#
# The correct answer is:
#
# Option 1, Class: ['academic major', 'natural science', 'academic discipline', 'natural science', 'mathematical term', 'natural science'], Description: ['field of study']
#
# ### Explanation
#
# In mathematics, is a sentence that refers to the field of study called "mathematics". The entity "mathematics" in this sentence can be described as a field of study.
#
#
#
# ====================================================================================================
# NEL task ends
#
# Predicted ID = 'Q395'
# ====================================================================================================
#
# 100 Wiki ID Matched
# ###########  PERFORMANCE   ###########
# Precision:53.0 %
# Recall: 97.0 %
#  Fmeasure = 69.28104575163398 %
# #####################################
